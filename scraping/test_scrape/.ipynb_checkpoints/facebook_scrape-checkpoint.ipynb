# %%
from snscrape.modules.facebook import FacebookUserScraper, FacebookCommunityScraper

# %%
scraper = FacebookUserScraper(username='bbc')

res = scraper.get_items()
list(res)
# Out:
# []

# %%
"""
Download comments for a public Facebook post.
"""

import facebook_scraper as fs

# get POST_ID from the URL of the post which can have the following structure:
# https://www.facebook.com/USER/posts/POST_ID
# https://www.facebook.com/groups/GROUP_ID/posts/POST_ID
POST_ID = "pfbid02NsuAiBU9o1ouwBrw1vYAQ7khcVXvz8F8zMvkVat9UJ6uiwdgojgddQRLpXcVBqYbl"

# number of comments to download -- set this to True to download all comments
MAX_COMMENTS = 100

# get the post (this gives a generator)
gen = fs.get_posts(
    post_urls=[POST_ID],
    options={"comments": MAX_COMMENTS, "progress": True}
)

# take 1st element of the generator which is the post we requested
post = next(gen)

# extract the comments part
comments = post['comments_full']

# process comments as you want...
for comment in comments:

    # e.g. ...print them
    print(comment)

    # e.g. ...get the replies for them
    for reply in comment['replies']:
        print(' ', reply)
# Out:
# C:\Users\linzh\anaconda3\envs\anlp\Lib\site-packages\facebook_scraper\facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'comment_id': '569787964750184', 'comment_url': 'https://facebook.com/569787964750184', 'commenter_id': '100007093505056', 'commenter_url': None, 'commenter_name': 'Sass Bálint', 'commenter_meta': None, 'comment_text': 'Izgalmas!', 'comment_time': datetime.datetime(2023, 1, 26, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}
# ...

# %%
from facebook_scraper import get_profile
get_profile("bbc") # Or get_profile("zuck", cookies="cookies.txt")
# Out:
# {'Friend_count': None,
#  'Follower_count': None,
#  'Following_count': None,
#  'cover_photo': 'https://scontent-sjc3-1.xx.fbcdn.net/v/t39.30808-6/394273051_866841021470181_6159635203652286639_n.png?stp=cp0_dst-jpg_e15_fr_q65&_nc_cat=105&ccb=1-7&_nc_sid=5f2048&_nc_ohc=eaki-8xKTtYAX-RHc8L&_nc_oc=AQknBCqpqLOebidioqb_25aQ6TSUw9DlbReuu7Vl3SehCxafLDqaF5LSpvFLHbTmYJQM9egfZvehnSUI6-1IG75K&_nc_ht=scontent-sjc3-1.xx&oh=00_AfDMHHvPtaqTWAfcna_cC3k2HMrlhup_K0DdoDu7qPV3GQ&oe=653E403A',
#  'profile_picture': 'https://scontent-sjc3-1.xx.fbcdn.net/v/t39.30808-1/245330608_5300122836669539_378388837082703204_n.png?stp=dst-png_p120x120&_nc_cat=1&ccb=1-7&_nc_sid=5f2048&_nc_ohc=gKHgDHc33MgAX9UHGsS&_nc_ht=scontent-sjc3-1.xx&oh=00_AfC4SK1xTNO56_2XB0V-gAaut_xFnox29iayek6oPXk92Q&oe=653F2C09',
#  'id': '100044328734711',
#  'Name': 'BBC',
# ...

# %%
from facebook_scraper import get_posts

for post in get_posts('bbc', pages=1):
    print(post['text'][:50])
# Out:
# C:\Users\linzh\anaconda3\envs\anlp\Lib\site-packages\IPython\core\interactiveshell.py:3508: UserWarning: A low page limit (<=2) might return no results, try increasing the limit
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
list(get_posts(group='thenintendoswitch'))
# Out:
# C:\Users\linzh\anaconda3\envs\anlp\Lib\site-packages\facebook_scraper\facebook_scraper.py:908: UserWarning: Facebook served mbasic/noscript content unexpectedly on https://m.facebook.com/groups/thenintendoswitch/permalink/6734277756637440/?_rdr
#   warnings.warn(
# C:\Users\linzh\anaconda3\envs\anlp\Lib\site-packages\facebook_scraper\facebook_scraper.py:908: UserWarning: Facebook served mbasic/noscript content unexpectedly on https://m.facebook.com/groups/thenintendoswitch/permalink/6809272925804589/?_rdr
#   warnings.warn(
# C:\Users\linzh\anaconda3\envs\anlp\Lib\site-packages\facebook_scraper\facebook_scraper.py:908: UserWarning: Facebook served mbasic/noscript content unexpectedly on https://m.facebook.com/groups/thenintendoswitch/permalink/6822467667818448/?_rdr
#   warnings.warn(
# ...
